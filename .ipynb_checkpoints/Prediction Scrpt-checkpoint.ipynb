# %% [markdown]
# # Nashville Area Housing Sales Price Prediction

# %% [markdown]
# ## Nashville Data cleaning

# %%
# import cleaning packages 
import pandas as pd
import pickle as pk
import numpy as np

# %%
# read the Nashville raw data 
raw_data = pd.read_excel("Nashville_raw_data.xlsx")

# %%
# view the raw data
raw_data
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000
# ...                                    ...        ...        ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844
#
#          LegalReference SoldAsVacant                           OwnerName  \
# 0      20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1      20140619-0053768           No             BONER, CHARLES & LESLIE
# 2      20160927-0101718           No           WILSON, JAMES E. & JOANNE
# 3      20160129-0008913           No            BAKER, JAY K. & SUSAN E.
# 4      20141015-0095255           No  POST, CHRISTOPHER M. & SAMANTHA C.
# ...                 ...          ...                                 ...
# 56472  20150608-0053286           No                                 NaN
# 56473  20150304-0019013           No                                 NaN
# 56474  20160819-0087214          Yes                                 NaN
# 56475  20160919-0098411          Yes                                 NaN
# 56476  20160919-0098411          Yes                                 NaN
#
#                                  OwnerAddress  Acreage  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3
# 1      1832  FOX CHASE DR, GOODLETTSVILLE, TN      3.5
# 2      1864  FOX CHASE DR, GOODLETTSVILLE, TN      2.9
# 3      1853  FOX CHASE DR, GOODLETTSVILLE, TN      2.6
# 4      1829  FOX CHASE DR, GOODLETTSVILLE, TN      2.0
# ...                                       ...      ...
# 56472                                     NaN      NaN
# 56473                                     NaN      NaN
# 56474                                     NaN      NaN
# 56475                                     NaN      NaN
# 56476                                     NaN      NaN
#
#                      TaxDistrict  LandValue  BuildingValue  TotalValue  \
# 0      GENERAL SERVICES DISTRICT    50000.0       168200.0    235700.0
# 1      GENERAL SERVICES DISTRICT    50000.0       264100.0    319000.0
# 2      GENERAL SERVICES DISTRICT    50000.0       216200.0    298000.0
# 3      GENERAL SERVICES DISTRICT    50000.0       147300.0    197300.0
# 4      GENERAL SERVICES DISTRICT    50000.0       152300.0    202300.0
# ...                          ...        ...            ...         ...
# 56472                        NaN        NaN            NaN         NaN
# 56473                        NaN        NaN            NaN         NaN
# 56474                        NaN        NaN            NaN         NaN
# 56475                        NaN        NaN            NaN         NaN
# 56476                        NaN        NaN            NaN         NaN
#
#        YearBuilt  Bedrooms  FullBath  HalfBath
# 0         1986.0       3.0       3.0       0.0
# 1         1998.0       3.0       3.0       2.0
# 2         1987.0       4.0       3.0       0.0
# 3         1985.0       3.0       3.0       0.0
# 4         1984.0       4.0       3.0       0.0
# ...          ...       ...       ...       ...
# 56472        NaN       NaN       NaN       NaN
# 56473        NaN       NaN       NaN       NaN
# 56474        NaN       NaN       NaN       NaN
# 56475        NaN       NaN       NaN       NaN
# 56476        NaN       NaN       NaN       NaN
#
# [56477 rows x 19 columns]

# %%
# convert the date column to numeric
raw_data["saledate_float"] = pd.to_numeric(raw_data["SaleDate"])
raw_data
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000
# ...                                    ...        ...        ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844
#
#          LegalReference SoldAsVacant                           OwnerName  \
# 0      20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1      20140619-0053768           No             BONER, CHARLES & LESLIE
# 2      20160927-0101718           No           WILSON, JAMES E. & JOANNE
# 3      20160129-0008913           No            BAKER, JAY K. & SUSAN E.
# 4      20141015-0095255           No  POST, CHRISTOPHER M. & SAMANTHA C.
# ...                 ...          ...                                 ...
# 56472  20150608-0053286           No                                 NaN
# 56473  20150304-0019013           No                                 NaN
# 56474  20160819-0087214          Yes                                 NaN
# 56475  20160919-0098411          Yes                                 NaN
# 56476  20160919-0098411          Yes                                 NaN
#
#                                  OwnerAddress  Acreage  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3
# 1      1832  FOX CHASE DR, GOODLETTSVILLE, TN      3.5
# 2      1864  FOX CHASE DR, GOODLETTSVILLE, TN      2.9
# 3      1853  FOX CHASE DR, GOODLETTSVILLE, TN      2.6
# 4      1829  FOX CHASE DR, GOODLETTSVILLE, TN      2.0
# ...                                       ...      ...
# 56472                                     NaN      NaN
# 56473                                     NaN      NaN
# 56474                                     NaN      NaN
# 56475                                     NaN      NaN
# 56476                                     NaN      NaN
#
#                      TaxDistrict  LandValue  BuildingValue  TotalValue  \
# 0      GENERAL SERVICES DISTRICT    50000.0       168200.0    235700.0
# 1      GENERAL SERVICES DISTRICT    50000.0       264100.0    319000.0
# 2      GENERAL SERVICES DISTRICT    50000.0       216200.0    298000.0
# 3      GENERAL SERVICES DISTRICT    50000.0       147300.0    197300.0
# 4      GENERAL SERVICES DISTRICT    50000.0       152300.0    202300.0
# ...                          ...        ...            ...         ...
# 56472                        NaN        NaN            NaN         NaN
# 56473                        NaN        NaN            NaN         NaN
# 56474                        NaN        NaN            NaN         NaN
# 56475                        NaN        NaN            NaN         NaN
# 56476                        NaN        NaN            NaN         NaN
#
#        YearBuilt  Bedrooms  FullBath  HalfBath       saledate_float
# 0         1986.0       3.0       3.0       0.0  1365465600000000000
# 1         1998.0       3.0       3.0       2.0  1402358400000000000
# 2         1987.0       4.0       3.0       0.0  1474848000000000000
# 3         1985.0       3.0       3.0       0.0  1454025600000000000
# 4         1984.0       4.0       3.0       0.0  1412899200000000000
# ...          ...       ...       ...       ...                  ...
# 56472        NaN       NaN       NaN       NaN  1432684800000000000
# 56473        NaN       NaN       NaN       NaN  1425254400000000000
# 56474        NaN       NaN       NaN       NaN  1471305600000000000
# 56475        NaN       NaN       NaN       NaN  1473206400000000000
# 56476        NaN       NaN       NaN       NaN  1473206400000000000
#
# [56477 rows x 20 columns]

# %%
# load the raw data into a data frame for cleaning
nash_df = pd.DataFrame(raw_data)

# %%
nash_df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000
# ...                                    ...        ...        ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844
#
#          LegalReference SoldAsVacant                           OwnerName  \
# 0      20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1      20140619-0053768           No             BONER, CHARLES & LESLIE
# 2      20160927-0101718           No           WILSON, JAMES E. & JOANNE
# 3      20160129-0008913           No            BAKER, JAY K. & SUSAN E.
# 4      20141015-0095255           No  POST, CHRISTOPHER M. & SAMANTHA C.
# ...                 ...          ...                                 ...
# 56472  20150608-0053286           No                                 NaN
# 56473  20150304-0019013           No                                 NaN
# 56474  20160819-0087214          Yes                                 NaN
# 56475  20160919-0098411          Yes                                 NaN
# 56476  20160919-0098411          Yes                                 NaN
#
#                                  OwnerAddress  Acreage  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3
# 1      1832  FOX CHASE DR, GOODLETTSVILLE, TN      3.5
# 2      1864  FOX CHASE DR, GOODLETTSVILLE, TN      2.9
# 3      1853  FOX CHASE DR, GOODLETTSVILLE, TN      2.6
# 4      1829  FOX CHASE DR, GOODLETTSVILLE, TN      2.0
# ...                                       ...      ...
# 56472                                     NaN      NaN
# 56473                                     NaN      NaN
# 56474                                     NaN      NaN
# 56475                                     NaN      NaN
# 56476                                     NaN      NaN
#
#                      TaxDistrict  LandValue  BuildingValue  TotalValue  \
# 0      GENERAL SERVICES DISTRICT    50000.0       168200.0    235700.0
# 1      GENERAL SERVICES DISTRICT    50000.0       264100.0    319000.0
# 2      GENERAL SERVICES DISTRICT    50000.0       216200.0    298000.0
# 3      GENERAL SERVICES DISTRICT    50000.0       147300.0    197300.0
# 4      GENERAL SERVICES DISTRICT    50000.0       152300.0    202300.0
# ...                          ...        ...            ...         ...
# 56472                        NaN        NaN            NaN         NaN
# 56473                        NaN        NaN            NaN         NaN
# 56474                        NaN        NaN            NaN         NaN
# 56475                        NaN        NaN            NaN         NaN
# 56476                        NaN        NaN            NaN         NaN
#
#        YearBuilt  Bedrooms  FullBath  HalfBath       saledate_float
# 0         1986.0       3.0       3.0       0.0  1365465600000000000
# 1         1998.0       3.0       3.0       2.0  1402358400000000000
# 2         1987.0       4.0       3.0       0.0  1474848000000000000
# 3         1985.0       3.0       3.0       0.0  1454025600000000000
# 4         1984.0       4.0       3.0       0.0  1412899200000000000
# ...          ...       ...       ...       ...                  ...
# 56472        NaN       NaN       NaN       NaN  1432684800000000000
# 56473        NaN       NaN       NaN       NaN  1425254400000000000
# 56474        NaN       NaN       NaN       NaN  1471305600000000000
# 56475        NaN       NaN       NaN       NaN  1473206400000000000
# 56476        NaN       NaN       NaN       NaN  1473206400000000000
#
# [56477 rows x 20 columns]

# %%
# list all columns available in the dataset
nash_df.columns
# Out:
# Index(['UniqueID ', 'ParcelID', 'LandUse', 'PropertyAddress', 'SaleDate',
#        'SalePrice', 'LegalReference', 'SoldAsVacant', 'OwnerName',
#        'OwnerAddress', 'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue',
#        'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath',
#        'saledate_float'],
#       dtype='object')

# %%
# create a dataset with the interested columns for the sale price prediction
nash_main = pd.DataFrame(nash_df[['PropertyAddress', 'saledate_float',
       'SalePrice', 'Acreage', 'LandValue', 'BuildingValue',
       'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath']])

# %%
# view main data
nash_main
# Out:
#                            PropertyAddress       saledate_float  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE  1365465600000000000     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE  1402358400000000000     366000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE  1474848000000000000     435000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE  1454025600000000000     255000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE  1412899200000000000     278000
# ...                                    ...                  ...        ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE  1432684800000000000     157500
# 56473  1423  WINDING CREEK DR, NOLENSVILLE  1425254400000000000     145000
# 56474    1804 GRACE POINT  LN, NOLENSVILLE  1471305600000000000     234611
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE  1473206400000000000      93844
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE  1473206400000000000      93844
#
#        Acreage  LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  \
# 0          2.3    50000.0       168200.0    235700.0     1986.0       3.0
# 1          3.5    50000.0       264100.0    319000.0     1998.0       3.0
# 2          2.9    50000.0       216200.0    298000.0     1987.0       4.0
# 3          2.6    50000.0       147300.0    197300.0     1985.0       3.0
# 4          2.0    50000.0       152300.0    202300.0     1984.0       4.0
# ...        ...        ...            ...         ...        ...       ...
# 56472      NaN        NaN            NaN         NaN        NaN       NaN
# 56473      NaN        NaN            NaN         NaN        NaN       NaN
# 56474      NaN        NaN            NaN         NaN        NaN       NaN
# 56475      NaN        NaN            NaN         NaN        NaN       NaN
# 56476      NaN        NaN            NaN         NaN        NaN       NaN
#
#        FullBath  HalfBath
# 0           3.0       0.0
# 1           3.0       2.0
# 2           3.0       0.0
# 3           3.0       0.0
# 4           3.0       0.0
# ...         ...       ...
# 56472       NaN       NaN
# 56473       NaN       NaN
# 56474       NaN       NaN
# 56475       NaN       NaN
# 56476       NaN       NaN
#
# [56477 rows x 11 columns]

# %%
# Check for missing values in the dataset to be used
nash_main.isnull().sum()
# Out:
# PropertyAddress       29
# saledate_float         0
# SalePrice              0
# Acreage            30462
# LandValue          30462
# BuildingValue      30462
# TotalValue         30462
# YearBuilt          32314
# Bedrooms           32320
# FullBath           32202
# HalfBath           32333
# dtype: int64

# %%
# Check valid vaules count in dataset.
nash_main.count()
# Out:
# PropertyAddress    56448
# saledate_float     56477
# SalePrice          56477
# Acreage            26015
# LandValue          26015
# BuildingValue      26015
# TotalValue         26015
# YearBuilt          24163
# Bedrooms           24157
# FullBath           24275
# HalfBath           24144
# dtype: int64

# %%
# drop all rows with any column with missing vaule
nash_main = nash_main.dropna(axis = "index", how = "any")

# %%
nash_main
# Out:
#                           PropertyAddress       saledate_float  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE  1365465600000000000     240000
# 1      1832  FOX CHASE DR, GOODLETTSVILLE  1402358400000000000     366000
# 2      1864 FOX CHASE  DR, GOODLETTSVILLE  1474848000000000000     435000
# 3      1853  FOX CHASE DR, GOODLETTSVILLE  1454025600000000000     255000
# 4      1829  FOX CHASE DR, GOODLETTSVILLE  1412899200000000000     278000
# ...                                   ...                  ...        ...
# 54210            6640 HOLT  RD, NASHVILLE  1467936000000000000     258000
# 54211            6608  HOLT RD, NASHVILLE  1437955200000000000     339528
# 54212            6635  HOLT RD, NASHVILLE  1409875200000000000     230000
# 54213         6552  REDMOND LN, NASHVILLE  1416787200000000000     237900
# 54214       105  HOLT HILLS RD, NASHVILLE  1415750400000000000     259000
#
#        Acreage  LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  \
# 0         2.30    50000.0       168200.0    235700.0     1986.0       3.0
# 1         3.50    50000.0       264100.0    319000.0     1998.0       3.0
# 2         2.90    50000.0       216200.0    298000.0     1987.0       4.0
# 3         2.60    50000.0       147300.0    197300.0     1985.0       3.0
# 4         2.00    50000.0       152300.0    202300.0     1984.0       4.0
# ...        ...        ...            ...         ...        ...       ...
# 54210     3.00   111000.0       155800.0    268000.0     1978.0       4.0
# 54211     3.00   111000.0       141700.0    252700.0     1978.0       3.0
# 54212     3.03   111500.0       210400.0    321900.0     1980.0       3.0
# 54213     1.03    59000.0       104100.0    163100.0     1985.0       3.0
# 54214     0.46    59000.0       194000.0    253000.0     2001.0       3.0
#
#        FullBath  HalfBath
# 0           3.0       0.0
# 1           3.0       2.0
# 2           3.0       0.0
# 3           3.0       0.0
# 4           3.0       0.0
# ...         ...       ...
# 54210       2.0       0.0
# 54211       2.0       0.0
# 54212       2.0       0.0
# 54213       3.0       0.0
# 54214       2.0       1.0
#
# [23995 rows x 11 columns]

# %%
# check to confirm all missing row are droped
nash_main.isnull().sum()
# Out:
# PropertyAddress    0
# saledate_float     0
# SalePrice          0
# Acreage            0
# LandValue          0
# BuildingValue      0
# TotalValue         0
# YearBuilt          0
# Bedrooms           0
# FullBath           0
# HalfBath           0
# dtype: int64

# %%
# confirm the datatype for each column
nash_main.dtypes
# Out:
# PropertyAddress     object
# saledate_float       int64
# SalePrice            int64
# Acreage            float64
# LandValue          float64
# BuildingValue      float64
# TotalValue         float64
# YearBuilt          float64
# Bedrooms           float64
# FullBath           float64
# HalfBath           float64
# dtype: object

# %%
# Remove duplicate from dataset
nash_main = nash_main.drop_duplicates()

# %%
nash_main
# Out:
#                           PropertyAddress       saledate_float  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE  1365465600000000000     240000
# 1      1832  FOX CHASE DR, GOODLETTSVILLE  1402358400000000000     366000
# 2      1864 FOX CHASE  DR, GOODLETTSVILLE  1474848000000000000     435000
# 3      1853  FOX CHASE DR, GOODLETTSVILLE  1454025600000000000     255000
# 4      1829  FOX CHASE DR, GOODLETTSVILLE  1412899200000000000     278000
# ...                                   ...                  ...        ...
# 54210            6640 HOLT  RD, NASHVILLE  1467936000000000000     258000
# 54211            6608  HOLT RD, NASHVILLE  1437955200000000000     339528
# 54212            6635  HOLT RD, NASHVILLE  1409875200000000000     230000
# 54213         6552  REDMOND LN, NASHVILLE  1416787200000000000     237900
# 54214       105  HOLT HILLS RD, NASHVILLE  1415750400000000000     259000
#
#        Acreage  LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  \
# 0         2.30    50000.0       168200.0    235700.0     1986.0       3.0
# 1         3.50    50000.0       264100.0    319000.0     1998.0       3.0
# 2         2.90    50000.0       216200.0    298000.0     1987.0       4.0
# 3         2.60    50000.0       147300.0    197300.0     1985.0       3.0
# 4         2.00    50000.0       152300.0    202300.0     1984.0       4.0
# ...        ...        ...            ...         ...        ...       ...
# 54210     3.00   111000.0       155800.0    268000.0     1978.0       4.0
# 54211     3.00   111000.0       141700.0    252700.0     1978.0       3.0
# 54212     3.03   111500.0       210400.0    321900.0     1980.0       3.0
# 54213     1.03    59000.0       104100.0    163100.0     1985.0       3.0
# 54214     0.46    59000.0       194000.0    253000.0     2001.0       3.0
#
#        FullBath  HalfBath
# 0           3.0       0.0
# 1           3.0       2.0
# 2           3.0       0.0
# 3           3.0       0.0
# 4           3.0       0.0
# ...         ...       ...
# 54210       2.0       0.0
# 54211       2.0       0.0
# 54212       2.0       0.0
# 54213       3.0       0.0
# 54214       2.0       1.0
#
# [23927 rows x 11 columns]

# %%
nash_main["Area"] = nash_main["PropertyAddress"].str.split(",").str[1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
nash_main
# Out:
#                           PropertyAddress       saledate_float  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE  1365465600000000000     240000
# 1      1832  FOX CHASE DR, GOODLETTSVILLE  1402358400000000000     366000
# 2      1864 FOX CHASE  DR, GOODLETTSVILLE  1474848000000000000     435000
# 3      1853  FOX CHASE DR, GOODLETTSVILLE  1454025600000000000     255000
# 4      1829  FOX CHASE DR, GOODLETTSVILLE  1412899200000000000     278000
# ...                                   ...                  ...        ...
# 54210            6640 HOLT  RD, NASHVILLE  1467936000000000000     258000
# 54211            6608  HOLT RD, NASHVILLE  1437955200000000000     339528
# 54212            6635  HOLT RD, NASHVILLE  1409875200000000000     230000
# 54213         6552  REDMOND LN, NASHVILLE  1416787200000000000     237900
# 54214       105  HOLT HILLS RD, NASHVILLE  1415750400000000000     259000
#
#        Acreage  LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  \
# 0         2.30    50000.0       168200.0    235700.0     1986.0       3.0
# 1         3.50    50000.0       264100.0    319000.0     1998.0       3.0
# 2         2.90    50000.0       216200.0    298000.0     1987.0       4.0
# 3         2.60    50000.0       147300.0    197300.0     1985.0       3.0
# 4         2.00    50000.0       152300.0    202300.0     1984.0       4.0
# ...        ...        ...            ...         ...        ...       ...
# 54210     3.00   111000.0       155800.0    268000.0     1978.0       4.0
# 54211     3.00   111000.0       141700.0    252700.0     1978.0       3.0
# 54212     3.03   111500.0       210400.0    321900.0     1980.0       3.0
# 54213     1.03    59000.0       104100.0    163100.0     1985.0       3.0
# 54214     0.46    59000.0       194000.0    253000.0     2001.0       3.0
#
#        FullBath  HalfBath             Area
# 0           3.0       0.0   GOODLETTSVILLE
# 1           3.0       2.0   GOODLETTSVILLE
# 2           3.0       0.0   GOODLETTSVILLE
# 3           3.0       0.0   GOODLETTSVILLE
# 4           3.0       0.0   GOODLETTSVILLE
# ...         ...       ...              ...
# 54210       2.0       0.0        NASHVILLE
# 54211       2.0       0.0        NASHVILLE
# 54212       2.0       0.0        NASHVILLE
# 54213       3.0       0.0        NASHVILLE
# 54214       2.0       1.0        NASHVILLE
#
# [23927 rows x 12 columns]

# %%
nash_main.columns
# Out:
# Index(['PropertyAddress', 'saledate_float', 'SalePrice', 'Acreage',
#        'LandValue', 'BuildingValue', 'TotalValue', 'YearBuilt', 'Bedrooms',
#        'FullBath', 'HalfBath', 'Area'],
#       dtype='object')

# %%
# Select columns and data needed
nash_main = pd.DataFrame(nash_main[['Area', 'saledate_float', 'SalePrice', 'Acreage', 'LandValue',
       'BuildingValue', 'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath',
       'HalfBath']])

# %%
nash_main
# Out:
#                   Area       saledate_float  SalePrice  Acreage  LandValue  \
# 0       GOODLETTSVILLE  1365465600000000000     240000     2.30    50000.0
# 1       GOODLETTSVILLE  1402358400000000000     366000     3.50    50000.0
# 2       GOODLETTSVILLE  1474848000000000000     435000     2.90    50000.0
# 3       GOODLETTSVILLE  1454025600000000000     255000     2.60    50000.0
# 4       GOODLETTSVILLE  1412899200000000000     278000     2.00    50000.0
# ...                ...                  ...        ...      ...        ...
# 54210        NASHVILLE  1467936000000000000     258000     3.00   111000.0
# 54211        NASHVILLE  1437955200000000000     339528     3.00   111000.0
# 54212        NASHVILLE  1409875200000000000     230000     3.03   111500.0
# 54213        NASHVILLE  1416787200000000000     237900     1.03    59000.0
# 54214        NASHVILLE  1415750400000000000     259000     0.46    59000.0
#
#        BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath
# 0           168200.0    235700.0     1986.0       3.0       3.0       0.0
# 1           264100.0    319000.0     1998.0       3.0       3.0       2.0
# 2           216200.0    298000.0     1987.0       4.0       3.0       0.0
# 3           147300.0    197300.0     1985.0       3.0       3.0       0.0
# 4           152300.0    202300.0     1984.0       4.0       3.0       0.0
# ...              ...         ...        ...       ...       ...       ...
# 54210       155800.0    268000.0     1978.0       4.0       2.0       0.0
# 54211       141700.0    252700.0     1978.0       3.0       2.0       0.0
# 54212       210400.0    321900.0     1980.0       3.0       2.0       0.0
# 54213       104100.0    163100.0     1985.0       3.0       3.0       0.0
# 54214       194000.0    253000.0     2001.0       3.0       2.0       1.0
#
# [23927 rows x 11 columns]

# %%
nash_main.dtypes
# Out:
# Area               object
# saledate_float      int64
# SalePrice           int64
# Acreage           float64
# LandValue         float64
# BuildingValue     float64
# TotalValue        float64
# YearBuilt         float64
# Bedrooms          float64
# FullBath          float64
# HalfBath          float64
# dtype: object

# %%
# Pickle the data
with open("nash_main.pkl", "wb") as file:
    pk.dump(nash_main, file)

# %% [markdown]
# -------------------------------

# %% [markdown]
# ## Training and Testing Data prep

# %%
# Load pickel data
with open("nash_main.pkl", "rb") as file:
    data_df = pk.load(file)

# %%
data_df
# Out:
#                   Area       saledate_float  SalePrice  Acreage  LandValue  \
# 0       GOODLETTSVILLE  1365465600000000000     240000     2.30    50000.0
# 1       GOODLETTSVILLE  1402358400000000000     366000     3.50    50000.0
# 2       GOODLETTSVILLE  1474848000000000000     435000     2.90    50000.0
# 3       GOODLETTSVILLE  1454025600000000000     255000     2.60    50000.0
# 4       GOODLETTSVILLE  1412899200000000000     278000     2.00    50000.0
# ...                ...                  ...        ...      ...        ...
# 54210        NASHVILLE  1467936000000000000     258000     3.00   111000.0
# 54211        NASHVILLE  1437955200000000000     339528     3.00   111000.0
# 54212        NASHVILLE  1409875200000000000     230000     3.03   111500.0
# 54213        NASHVILLE  1416787200000000000     237900     1.03    59000.0
# 54214        NASHVILLE  1415750400000000000     259000     0.46    59000.0
#
#        BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath
# 0           168200.0    235700.0     1986.0       3.0       3.0       0.0
# 1           264100.0    319000.0     1998.0       3.0       3.0       2.0
# 2           216200.0    298000.0     1987.0       4.0       3.0       0.0
# 3           147300.0    197300.0     1985.0       3.0       3.0       0.0
# 4           152300.0    202300.0     1984.0       4.0       3.0       0.0
# ...              ...         ...        ...       ...       ...       ...
# 54210       155800.0    268000.0     1978.0       4.0       2.0       0.0
# 54211       141700.0    252700.0     1978.0       3.0       2.0       0.0
# 54212       210400.0    321900.0     1980.0       3.0       2.0       0.0
# 54213       104100.0    163100.0     1985.0       3.0       3.0       0.0
# 54214       194000.0    253000.0     2001.0       3.0       2.0       1.0
#
# [23927 rows x 11 columns]

# %%
# Transform the Area column to numeric

# %%
# import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
# create an instance of label encoder
lab = LabelEncoder()

# %%
# Using .fit_transform function to fit label
# encoder and return encoded label
Area = lab.fit_transform(data_df["Area"])

# %%
Area
# Out:
# array([2, 2, 2, ..., 7, 7, 7])

# %%
data_df["Area"] = Area

# %%
data_df
# Out:
#        Area       saledate_float  SalePrice  Acreage  LandValue  \
# 0         2  1365465600000000000     240000     2.30    50000.0
# 1         2  1402358400000000000     366000     3.50    50000.0
# 2         2  1474848000000000000     435000     2.90    50000.0
# 3         2  1454025600000000000     255000     2.60    50000.0
# 4         2  1412899200000000000     278000     2.00    50000.0
# ...     ...                  ...        ...      ...        ...
# 54210     7  1467936000000000000     258000     3.00   111000.0
# 54211     7  1437955200000000000     339528     3.00   111000.0
# 54212     7  1409875200000000000     230000     3.03   111500.0
# 54213     7  1416787200000000000     237900     1.03    59000.0
# 54214     7  1415750400000000000     259000     0.46    59000.0
#
#        BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath
# 0           168200.0    235700.0     1986.0       3.0       3.0       0.0
# 1           264100.0    319000.0     1998.0       3.0       3.0       2.0
# 2           216200.0    298000.0     1987.0       4.0       3.0       0.0
# 3           147300.0    197300.0     1985.0       3.0       3.0       0.0
# 4           152300.0    202300.0     1984.0       4.0       3.0       0.0
# ...              ...         ...        ...       ...       ...       ...
# 54210       155800.0    268000.0     1978.0       4.0       2.0       0.0
# 54211       141700.0    252700.0     1978.0       3.0       2.0       0.0
# 54212       210400.0    321900.0     1980.0       3.0       2.0       0.0
# 54213       104100.0    163100.0     1985.0       3.0       3.0       0.0
# 54214       194000.0    253000.0     2001.0       3.0       2.0       1.0
#
# [23927 rows x 11 columns]

# %%
with open("TrainTest.pkl", "wb") as file:
    pk.dump(data_df, file)

# %%
# Convert dataframe to numpy for model training
x = data_df[['Area', 'saledate_float', 'Acreage', 'LandValue',
       'BuildingValue', 'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath',
       'HalfBath']]
x = x.to_numpy()

# %%
x
# Out:
# array([[2.0000000e+00, 1.3654656e+18, 2.3000000e+00, ..., 3.0000000e+00,
#         3.0000000e+00, 0.0000000e+00],
#        [2.0000000e+00, 1.4023584e+18, 3.5000000e+00, ..., 3.0000000e+00,
#         3.0000000e+00, 2.0000000e+00],
#        [2.0000000e+00, 1.4748480e+18, 2.9000000e+00, ..., 4.0000000e+00,
#         3.0000000e+00, 0.0000000e+00],
#        ...,
#        [7.0000000e+00, 1.4098752e+18, 3.0300000e+00, ..., 3.0000000e+00,
#         2.0000000e+00, 0.0000000e+00],
#        [7.0000000e+00, 1.4167872e+18, 1.0300000e+00, ..., 3.0000000e+00,
#         3.0000000e+00, 0.0000000e+00],
#        [7.0000000e+00, 1.4157504e+18, 4.6000000e-01, ..., 3.0000000e+00,
#         2.0000000e+00, 1.0000000e+00]])

# %%
y = data_df[["SalePrice"]]
y = y.to_numpy()

# %%
y
# Out:
# array([[240000],
#        [366000],
#        [435000],
#        ...,
#        [230000],
#        [237900],
#        [259000]], dtype=int64)

# %% [markdown]
# ## Split the Data to training and Testing

# %%
# import the sklearn split lib
from sklearn.model_selection import train_test_split

# %%
# Split the dataset (80% train and 20% test)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Build and Train the Sale price Model

# %%
# import the regression sklearn lib
from sklearn.linear_model import LinearRegression as rg

# %%
# fit the model with the train data
reg = rg().fit(x_train, y_train)

# %%
# view the coefficient of determination of the prediction(Score)
reg.score(x_train, y_train)
# Out:
# 0.7183716027845588

# %%
# check coefficent 
reg.coef_
# Out:
# array([[ 1.03144448e+01,  1.18088435e-12, -3.73042996e-01,
#         -1.87499410e+00, -2.58230340e+00,  3.23678827e+00,
#         -5.43095510e+02, -1.71440753e+00, -4.12258434e+00,
#         -1.87610110e+00]])

# %%
# check intercept
reg.intercept_
# Out:
# array([-553829.1475381])

# %% [markdown]
# # Test the price model

# %%
test_prediction = reg.predict(x_test)

# %%
test_prediction
# Out:
# array([[829456.93313988],
#        [161853.86626545],
#        [287082.27764766],
#        ...,
#        [578124.71220144],
#        [284293.20491026],
#        [224414.95484097]])

# %%
y_test
# Out:
# array([[895000],
#        [100000],
#        [274500],
#        ...,
#        [910000],
#        [210000],
#        [235000]], dtype=int64)
